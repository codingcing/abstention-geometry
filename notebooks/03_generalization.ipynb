# %% [markdown]
# # 03 — Cross-topic generalisation
#
# Does the abstention direction transfer across question topics? Leave-one-topic-out logistic probe at the peak layer from 02.
#
# **Inputs:** `acts_layer_{peak}.pt`, `labels.csv`, `probe_accuracy.csv` (results dir).
# **Outputs:** `generalization.csv` (results dir), `figures/generalization_by_topic.png`.

# %%
# Colab setup (skip locally)
# !git pull
# from google.colab import drive; drive.mount('/content/drive')
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
import pandas as pd

from src.paths import results_dir
from src.probes import load_activations
from src.generalization import cross_topic_eval, run_all_holdouts, plot_generalization

# %%
RESULTS_DIR = results_dir()  # Drive on Colab, repo results/ locally; override with $RESULTS_DIR
print('RESULTS_DIR =', RESULTS_DIR)

# %% [markdown]
# ## Identify peak layer from 02

# %%
# TODO: probe_df = pd.read_csv(RESULTS_DIR + 'probe_accuracy.csv')
# TODO: peak_layer = int(probe_df.loc[probe_df['mean_balanced_accuracy'].idxmax(), 'layer'])

# %% [markdown]
# ## Build (topic, label) frame aligned to cached activations
#
# Order must match the order used in 01_cache_activations.ipynb.

# %%
# TODO: labels_df = pd.read_csv(RESULTS_DIR + 'labels.csv')[['topic', 'answerable']]
# TODO: acts_by_layer = load_activations(RESULTS_DIR, layers=[peak_layer])

# %% [markdown]
# ## Leave-one-topic-out sweep

# %%
# TODO: gen_df = run_all_holdouts(acts_by_layer, labels_df, peak_layer)
# TODO: gen_df.to_csv(RESULTS_DIR + 'generalization.csv', index=False)
# TODO: plot_generalization(gen_df, save_path='../figures/generalization_by_topic.png')

# %% [markdown]
# ## Spot check — held-out test accuracy distribution

# %%
# TODO: print mean / std / min / max of gen_df['test_acc']; flag any topic where the probe collapses.
